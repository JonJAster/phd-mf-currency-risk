# %% [markdown]
# Checking the contents of grouped mutual fund files

# %%
using CSV
using DataFrames

mf_data1 = CSV.read("../../Data/Refined Data/Mutual Funds/Grouped Files/local-monthly-gross-returns/mf_local-monthly-gross-returns_other.csv", DataFrame);

# %%
first(mf_data1, 5)
# Out:
# 5×615 DataFrame
#  Row │ name                               fundid      secid       1970-01  1970-02  1970-03  1970 ⋯
#      │ String                             String15?   String15    Missing  Missing  Missing  Miss ⋯
# ─────┼─────────────────────────────────────────────────────────────────────────────────────────────
#    1 │ AAB AEX Garantie Fonds Acc         FSGBR04TGC  F0GBR051J3  missing  missing  missing  miss ⋯
#    2 │ AAB America Fd Inc                 FSGBR058OB  F0GBR04C0U  missing  missing  missing  miss
#    3 │ AAB Asian Tigers Fd Inc            FSGBR058O0  F0GBR04C07  missing  missing  missing  miss
#    4 │ AAB BeleggingsFds voor Medici Acc  FSGBR058LF  F0GBR04B2Q  missing  missing  missing  miss
#    5 │ AAB Dyn Intl Gar Fds 1             FSGBR04O5G  F0GBR051LI  missing  missing  missing  miss ⋯
#                                                                                 609 columns omitted
