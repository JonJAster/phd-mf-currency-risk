# %% [markdown]
# Checking why fund data dates are not end of month aligned

# %%
using DataFrames
using CSV

data = CSV.read("../../data/transformed/mutual-funds/local-rets/mf_can-chn-jpn.csv", DataFrame)
# Out:
# 512099×9 DataFrame
#     Row │ fundid      date        ret_gross_m  ret_net_m   mean_costs  approx_morningstar_categor ⋯
#         │ String15    Date        Float64?     Float64?    Float64?    String                     ⋯
# ────────┼──────────────────────────────────────────────────────────────────────────────────────────
#       1 │ FS00008KO2  2011-09-01    -7.25294   -7.39063      0.148466  Canada Fund Canadian Equit ⋯
#       2 │ FS00008KO2  2011-10-01     5.42708    5.27058      0.148449  Canada Fund Canadian Equit
#       3 │ FS00008KO2  2011-11-01     0.162961   0.014289     0.148431  Canada Fund Canadian Equit
#       4 │ FS00008KO2  2011-12-01    -1.69482   -1.84073      0.148414  Canada Fund Canadian Equit
#       5 │ FS00008KO2  2012-01-01     5.40621    5.23998      0.157714  Canada Fund Canadian Equit ⋯
#       6 │ FS00008KO2  2012-02-01     0.991044   0.843078     0.146541  Canada Fund Canadian Equit
# ...
