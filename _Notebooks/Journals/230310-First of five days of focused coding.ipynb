# %% [markdown]
# I will carry out the research steps set out previously with the goal of finishing the last step by March 14th. I will keep note of any issues that I had to put aside in order to finish on time in notebooks, and then will revisit them after I've finished.

# %% [markdown]
# Issue: I'm missing part 8 of the mutual fund info data, as this file part was overwritten with the wrong data. I have already re-downloaded it, but it doesn't look like the re-download has updated on OneDrive yet, so I don't have access to it.

# %% [markdown]
# I think I'm finished with the code to regroup mutual fund data by country, but when I run the debugger it immediately halts without errors and without even reaching line 1 of the program. It used to work fine, so I'm puzzled.

# %% [markdown]
# Issue: Monthly costs file part 11 is gross returns data instead of costs data. I've deleted it for now.

# %% [markdown]
# I'm getting a strange error now where it says the column names of monthly costs part 10 and monthly costs part 12 don't match, although they look exactly the same. I'm going to look into that now.

# %%
using CSV
using DataFrames

data1 = CSV.read("../Data/Raw Data/Mutual Funds/monthly-costs/mf_monthly-costs_part-10.csv", DataFrame)
data2 = CSV.read("../Data/Raw Data/Mutual Funds/monthly-costs/mf_monthly-costs_part-12.csv", DataFrame)
# Out:
# 49946×387 DataFrame
#    Row │ Name                               FundId      SecId       Representative Cost Ex Transa ⋯
#        │ String                             String15    String15    Missing                       ⋯
# ───────┼───────────────────────────────────────────────────────────────────────────────────────────
#      1 │ IMGA Euro Taxa Variável I FIMA     FSUSA0BGCF  F0000174QW                                ⋯
#      2 │ Indosuez Funds Sustainable Plane…  FS0000GOMX  F000016L4G
#      3 │ Indosuez Funds Sustainable Plane…  FS0000GOMX  F000016L4M
#      4 │ Concerto IS - Multiple Opp A EUR   FS0000G9WR  F00001D8EE
#      5 │ Fidelity Enhanced Reserve Y MInc…  FS0000DPEN  F000016LV9                                ⋯
#      6 │ RAM (Lux) Tactical Glb Bd Total …  FSUSA0A8PP  F000015NNF
#      7 │ Schwab High Yield Municipal Bond…  FS0000FZ73  F0000152MM
#      8 │ Dummy CAM AC USD                   FS0000G4GX  F000015EEW
# ...

# %%
println(names(data1))
# Out:
# ["Name", "FundId", "SecId", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-01", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-02", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-03", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-04", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-05", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-06", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-07", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-08", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-09", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-10", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-11", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-12", "Representative Cost Ex Transaction Fee (Unannualised) \n1991-01", "Representative Cost Ex Transaction Fee (Unannualised) \n1991-02", "Representative Cost Ex Transact
# ...

# %%
println(names(data2))
# Out:
# ["Name", "FundId", "SecId", "Representative Cost Ex Transaction Fee (Unannualised) \r\n1990-01", "Representative Cost Ex Transaction Fee (Unannualised) \r\n1990-02", "Representative Cost Ex Transaction Fee (Unannualised) \r\n1990-03", "Representative Cost Ex Transaction Fee (Unannualised) \r\n1990-04", "Representative Cost Ex Transaction Fee (Unannualised) \r\n1990-05", "Representative Cost Ex Transaction Fee (Unannualised) \r\n1990-06", "Representative Cost Ex Transaction Fee (Unannualised) \r\n1990-07", "Representative Cost Ex Transaction Fee (Unannualised) \r\n1990-08", "Representative Cost Ex Transaction Fee (Unannualised) \r\n1990-09", "Representative Cost Ex Transaction Fee (Unannualised) \r\n1990-10", "Representative Cost Ex Transaction Fee (Unannualised) \r\n1990-11", "Representative Cost Ex Transaction Fee (Unannualised) \r\n1990-12", "Representative Cost Ex Transaction Fee (Unannualised) \r\n1991-01", "Representative Cost Ex Transaction Fee (Unannualised) \r\n1991-02", "Rep
# ...

# %% [markdown]
# Okay, I've edited the files and copied the headings from 10 into 12 and 13. Let's try that again.

# %%
using CSV
using DataFrames

data1 = CSV.read("../Data/Raw Data/Mutual Funds/monthly-costs/mf_monthly-costs_part-10.csv", DataFrame)
data2 = CSV.read("../Data/Raw Data/Mutual Funds/monthly-costs/mf_monthly-costs_part-12.csv", DataFrame)
# Out:
# 49946×387 DataFrame
#    Row │ Name                               FundId      SecId       Representative Cost Ex Transa ⋯
#        │ String                             String15    String15    Missing                       ⋯
# ───────┼───────────────────────────────────────────────────────────────────────────────────────────
#      1 │ IMGA Euro Taxa Variável I FIMA     FSUSA0BGCF  F0000174QW                                ⋯
#      2 │ Indosuez Funds Sustainable Plane…  FS0000GOMX  F000016L4G
#      3 │ Indosuez Funds Sustainable Plane…  FS0000GOMX  F000016L4M
#      4 │ Concerto IS - Multiple Opp A EUR   FS0000G9WR  F00001D8EE
#      5 │ Fidelity Enhanced Reserve Y MInc…  FS0000DPEN  F000016LV9                                ⋯
#      6 │ RAM (Lux) Tactical Glb Bd Total …  FSUSA0A8PP  F000015NNF
#      7 │ Schwab High Yield Municipal Bond…  FS0000FZ73  F0000152MM
#      8 │ Dummy CAM AC USD                   FS0000G4GX  F000015EEW
# ...

# %%
println(names(data1))
# Out:
# ["Name", "FundId", "SecId", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-01", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-02", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-03", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-04", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-05", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-06", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-07", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-08", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-09", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-10", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-11", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-12", "Representative Cost Ex Transaction Fee (Unannualised) \n1991-01", "Representative Cost Ex Transaction Fee (Unannualised) \n1991-02", "Representative Cost Ex Transact
# ...

# %%
println(names(data2))
# Out:
# ["Name", "FundId", "SecId", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-01", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-02", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-03", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-04", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-05", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-06", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-07", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-08", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-09", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-10", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-11", "Representative Cost Ex Transaction Fee (Unannualised) \n1990-12", "Representative Cost Ex Transaction Fee (Unannualised) \n1991-01", "Representative Cost Ex Transaction Fee (Unannualised) \n1991-02", "Representative Cost Ex Transact
# ...

# %% [markdown]
# I have a similar problem now with the column names of net assets part 9.

# %%
using CSV
using DataFrames

data1 = CSV.read("../Data/Raw Data/Mutual Funds/monthly-net-assets/mf_monthly-net-assets_part-8.csv", DataFrame)
data2 = CSV.read("../Data/Raw Data/Mutual Funds/monthly-net-assets/mf_monthly-net-assets_part-9.csv", DataFrame);

# %%
println(names(data1))
# Out:
# ["Name", "FundId", "SecId", "Net Assets - share class (Monthly) (USD) \n1990-01 \nUSD", "Net Assets - share class (Monthly) (USD) \n1990-02 \nUSD", "Net Assets - share class (Monthly) (USD) \n1990-03 \nUSD", "Net Assets - share class (Monthly) (USD) \n1990-04 \nUSD", "Net Assets - share class (Monthly) (USD) \n1990-05 \nUSD", "Net Assets - share class (Monthly) (USD) \n1990-06 \nUSD", "Net Assets - share class (Monthly) (USD) \n1990-07 \nUSD", "Net Assets - share class (Monthly) (USD) \n1990-08 \nUSD", "Net Assets - share class (Monthly) (USD) \n1990-09 \nUSD", "Net Assets - share class (Monthly) (USD) \n1990-10 \nUSD", "Net Assets - share class (Monthly) (USD) \n1990-11 \nUSD", "Net Assets - share class (Monthly) (USD) \n1990-12 \nUSD", "Net Assets - share class (Monthly) (USD) \n1991-01 \nUSD", "Net Assets - share class (Monthly) (USD) \n1991-02 \nUSD", "Net Assets - share class (Monthly) (USD) \n1991-03 \nUSD", "Net Assets - share class (Monthly) (USD) \n1991-04 \nUSD", "Net Asset
# ...

# %%
println(names(data2))
# Out:
# ["Name", "FundId", "SecId", "Net Assets - share class (Monthly) (USD) \n1990-01 \nUSD", "Net Assets - share class (Monthly) (USD) \n1990-02 \nUSD", "Net Assets - share class (Monthly) (USD) \n1990-03 \nUSD", "Net Assets - share class (Monthly) (USD) \n1990-04 \nUSD", "Net Assets - share class (Monthly) (USD) \n1990-05 \nUSD", "Net Assets - share class (Monthly) (USD) \n1990-06 \nUSD", "Net Assets - share class (Monthly) (USD) \n1990-07 \nUSD", "Net Assets - share class (Monthly) (USD) \n1990-08 \nUSD", "Net Assets - share class (Monthly) (USD) \n1990-09 \nUSD", "Net Assets - share class (Monthly) (USD) \n1990-10 \nUSD", "Net Assets - share class (Monthly) (USD) \n1990-11 \nUSD", "Net Assets - share class (Monthly) (USD) \n1990-12 \nUSD", "Net Assets - share class (Monthly) (USD) \n1991-01 \nUSD", "Net Assets - share class (Monthly) (USD) \n1991-02 \nUSD", "Net Assets - share class (Monthly) (USD) \n1991-03 \nUSD", "Net Assets - share class (Monthly) (USD) \n1991-04 \nUSD", "Net Asset
# ...
