# %% [markdown]
# Checking the number of decimal places in sample data.

# %%
using DataFrames
using CSV

data1 = CSV.read("../../data/raw/currencies/spot_mid.csv", DataFrame)
data2 = CSV.read("../../data/raw/equities/factors/global_SMB.csv", DataFrame)
data3 = CSV.read("../../data/raw/equities/country_market_data.csv", DataFrame)
data4 = CSV.read("../../data/raw/mutual-funds/local-monthly-gross-returns/mf_local-monthly-gross-returns_part-1.csv", DataFrame);

# %%
display(first(data1, 2))
display(first(data2, 2))
display(first(data3, 2))
display(first(data4, 2))
# Out:
# 2×74 DataFrame
#  Row │ date        BBAUDSP  AUSTDO$  MBATSSP  AUSTSC$   BBBELSP  NBBECSP  BELGLU$  BBCADSP  CNDOL ⋯
#      │ String15    String7  String7  String7  String15  String7  String7  String7  String7  Strin ⋯
# ─────┼─────────────────────────────────────────────────────────────────────────────────────────────
#    1 │ 31/01/1976  NA       NA       NA       NA        NA       NA       NA       NA       NA    ⋯
#    2 │ 27/02/1976  NA       NA       NA       NA        NA       NA       NA       NA       NA
#                                                                                  65 columns omitted
# 2×8 DataFrame
#  Row │ location  name           freq     weighting  direction  n_countries  date        ret       ⋯
#      │ String7   String15       String7  String7    Int64      Int64        Date        Float64   ⋯
# ─────┼─────────────────────────────────────────────────────────────────────────────────────────────
# ...

# %%
println(data4[findfirst(!ismissing, data4[:, 300]), 300])
# Out:
# -1.06981
